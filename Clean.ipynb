# %%
# Dependencies

import pandas as pd

# %%
# Loading CSV

file_path = "Data/2021_US_Region_Mobility_Report.csv"
df_mob = pd.read_csv(file_path)

df_mob
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  US  United States          NaN          NaN         NaN
# 1                  US  United States          NaN          NaN         NaN
# 2                  US  United States          NaN          NaN         NaN
# 3                  US  United States          NaN          NaN         NaN
# 4                  US  United States          NaN          NaN         NaN
# 5                  US  United States          NaN          NaN         NaN
# 6                  US  United States          NaN          NaN         NaN
# 7                  US  United States          NaN          NaN         NaN
# 8                  US  United States          NaN          NaN         NaN
# 9                  US  United States          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# ...

# %%
df_mob = df_mob.dropna(subset = ['sub_region_1', 'census_fips_code'])

# %%
new_column_order = ["sub_region_1", "sub_region_2", "census_fips_code", "date", "retail_and_recreation_percent_change_from_baseline", "grocery_and_pharmacy_percent_change_from_baseline", "parks_percent_change_from_baseline", "workplaces_percent_change_from_baseline", "residential_percent_change_from_baseline"]

df_mob = df_mob[new_column_order]
df_mob.head(20)
# Out:
#     sub_region_1    sub_region_2  census_fips_code        date  \
# 730      Alabama  Autauga County            1001.0  2021-01-01
# 731      Alabama  Autauga County            1001.0  2021-01-02
# 732      Alabama  Autauga County            1001.0  2021-01-03
# 733      Alabama  Autauga County            1001.0  2021-01-04
# 734      Alabama  Autauga County            1001.0  2021-01-05
# 735      Alabama  Autauga County            1001.0  2021-01-06
# 736      Alabama  Autauga County            1001.0  2021-01-07
# 737      Alabama  Autauga County            1001.0  2021-01-08
# 738      Alabama  Autauga County            1001.0  2021-01-09
# 739      Alabama  Autauga County            1001.0  2021-01-10
# 740      Alabama  Autauga County            1001.0  2021-01-11
# 741      Alabama  Autauga County            1001.0  2021-01-12
# 742      Alabama  Autauga County            1001.0  2021-01-13
# 743      Alabama  Autauga County            1001.0  2021-01-14
# ...

# %%
df_mob
# Out:
#        sub_region_1    sub_region_2  census_fips_code        date  \
# 730         Alabama  Autauga County            1001.0  2021-01-01
# 731         Alabama  Autauga County            1001.0  2021-01-02
# 732         Alabama  Autauga County            1001.0  2021-01-03
# 733         Alabama  Autauga County            1001.0  2021-01-04
# 734         Alabama  Autauga County            1001.0  2021-01-05
# ...             ...             ...               ...         ...
# 951955      Wyoming   Weston County           56045.0  2021-12-27
# 951956      Wyoming   Weston County           56045.0  2021-12-28
# 951957      Wyoming   Weston County           56045.0  2021-12-29
# 951958      Wyoming   Weston County           56045.0  2021-12-30
# 951959      Wyoming   Weston County           56045.0  2021-12-31
#
#         retail_and_recreation_percent_change_from_baseline  \
# 730                                                 -46.0
# ...
